# %%
import requests
import json
import pandas as pd

# %%
bomen = requests.get('https://api.data.amsterdam.nl/v1/bomen/')

# %%
bomen
# Out:
# <Response [200]>

# %%
json_bomen = bomen.json()

# %%
json_bomen
# Out:
# {'openapi': '3.0.3',
#  'info': {'title': 'bomen',
#   'version': '1.2.0',
#   'description': 'dataset met actuele informatie over de bomen in beheer van gemeente Amsterdam',
#   'termsOfService': 'https://data.amsterdam.nl/',
#   'contact': {'email': 'datapunt@amsterdam.nl'},
#   'license': {'name': 'openbaar, tenzij anders aangegeven / behoudens uitzonderingen'}},
#  'paths': {'/v1/bomen/gebrekregistratie/': {'get': {'operationId': 'bomen_gebrekregistratie_list',
#     'description': 'bevat de actuele gebrekregistratie van de bomen in beheer van gemeente Amsterdam.',
#     'parameters': [{'in': 'header',
#       'name': 'Accept-Crs',
#       'schema': {'type': 'string'},
#       'description': 'Accept-Crs header for Geo queries'},
#      {'in': 'header',
#       'name': 'Content-Crs',
#       'schema': {'type': 'string'},
#       'description': 'Content-Crs header for Geo queries'},
#      {'in': 'header',
#       'name': 'X-Api-Key',
#       'schema': {'type': 'string'},
# ...
